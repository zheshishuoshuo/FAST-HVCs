# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(index=range(1000),columns=[1,'NAME','RAMIN','RAMAX'])
df
# Out:
#        1 NAME RAMIN RAMAX
# 0    NaN  NaN   NaN   NaN
# 1    NaN  NaN   NaN   NaN
# 2    NaN  NaN   NaN   NaN
# 3    NaN  NaN   NaN   NaN
# 4    NaN  NaN   NaN   NaN
# ..   ...  ...   ...   ...
# 995  NaN  NaN   NaN   NaN
# 996  NaN  NaN   NaN   NaN
# 997  NaN  NaN   NaN   NaN
# 998  NaN  NaN   NaN   NaN
# 999  NaN  NaN   NaN   NaN
#
# [1000 rows x 4 columns]

# %%
import time
#coding=utf-8 
import os
filePath = 'A:/KY'
n=0
for i,j,k in os.walk(filePath):
    # print(k)#直接输出文件名
    #一个文件名一行，输出
    
    for s in k:
        try:
            time_start_1 = time.time()
            n=n+1
            print(s)
            ss=filePath+'/'+s
            radec = get_radec_single(ss)
            ra_min,ra_max,dec_min,dec_max=return_radec(radec)
            df.loc[n,'NAME']=s
            df.loc[n,'RAMIN']=ra_min
            df.loc[n,'RAMAX']=ra_max


    # radec = get_radec_single('A:/KY/DEC+372236-9_2022_03_04_16_00_00_000.xlsx')
            time_end_1 = time.time()
            print("运行时间："+str(time_end_1 - time_start_1)+"秒")
        except Exception :
            pass
        continue
# Out:
# DEC+321913-7A_2022_05_20_15_00_29_000.xlsx
# 1
# 2
# check A:/KY/DEC+321913-7A_2022_05_20_15_00_29_000.xlsx
# Use astropy to convert Az, ZD to RA, DEC
# atmospheric pressure: 925.0 hPa
# ground-level temperature: 15.0 deg C
# relative humidity: 0.8
# beam 1
# 85.58365607145569 195.91957499408184
# 31.400217002593156 32.32714259493464
# 运行时间：28.119488954544067秒
# DEC+321913-8_2022_05_21_01_15_00_000.xlsx
# 1
# 2
# check A:/KY/DEC+321913-8_2022_05_21_01_15_00_000.xlsx
# Use astropy to convert Az, ZD to RA, DEC
# atmospheric pressure: 925.0 hPa
# ground-level temperature: 15.0 deg C
# relative humidity: 0.8
# beam 1
# 241.65407044506085 255.2635282830287
# 31.410782900113222 32.35630738213151
# 运行时间：3.8641929626464844秒
# DEC+324053-3-1_2022_06_29_18_50_00_000.xlsx
# 1
# 2
# check A:/KY/DEC+324053-3-1_2022_06_29_18_50_00_000.xlsx
# Use astropy to convert Az, ZD to RA, DEC
# atmospheric pressure: 925.0 hPa
# ground-level temperature: 15.0 deg C
# relative humidity: 0.8
# beam 1
# ...

# %%
df
# Out:
#        1                                         NAME       RAMIN       RAMAX
# 0    NaN                                          NaN         NaN         NaN
# 1    NaN   DEC+321913-7A_2022_05_20_15_00_29_000.xlsx   85.583656  195.919575
# 2    NaN    DEC+321913-8_2022_05_21_01_15_00_000.xlsx   241.65407  255.263528
# 3    NaN  DEC+324053-3-1_2022_06_29_18_50_00_000.xlsx           0           0
# 4    NaN    DEC+210727-2_2022_02_14_23_00_00_000.xlsx  115.964749  131.186606
# ..   ...                                          ...         ...         ...
# 995  NaN                                          NaN         NaN         NaN
# 996  NaN                                          NaN         NaN         NaN
# 997  NaN                                          NaN         NaN         NaN
# 998  NaN                                          NaN         NaN         NaN
# 999  NaN                                          NaN         NaN         NaN
#
# [1000 rows x 4 columns]

# %%
df.to_csv('df2.csv')

# %%
# for date in dates:
#     try:
#         data=pd.read_csv('A_stock/overview-push-%d/stock overview.csv' %date, encoding='gbk')
#         pieces.append(data)
#     except Exception :
#         pass
#     continue
